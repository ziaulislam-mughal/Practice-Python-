# %%
while True:
    a = float(input("ENter number "))
    b = float(input("ENter number "))
    operation = input("Enter operation  , or 'exit' to quit: ")

    if operation.lower() == "exit" or operation.lower() == "e":
        print("Good Bye")
        break

    if operation == "+":
        print(a + b)
    elif operation == "-":
        print(a - b)
    elif operation == "*":
        print(a * b)
    elif operation == "/":
        if b != 0:
            print(a / b)
        else:
            print("Error: Division by zero")
    else:
        print("Invalid operation")
        break
# Out:
# Invalid operation

# %%
discount = 0 
amount = float(input("Enter the amount : "))

if (amount > 1000 ) :
    discount = amount  * 10 / 100

print("Amount = ", amount - discount)
# Out:
# Amount =  3600.0

# %%
age = int(input("Enter your age : "))
if age >= 18 :
    print("you can vote .")
else :
    print("you cannot vote .")
# Out:
# you can vote .

# %%
marks = int(input("Enter marks"))

if marks >= 80 and marks <= 100 :
    print("A")
elif marks >= 60 :
    print("B")
elif marks < 50 :
    print("fail")
else :
    print("invalid input")
# Out:
# B

# %%
num = int(input("Enter number "))

if num > 0 :
    print(f"{num} is positive ")
elif num < 0 :
    print(f"{num} is negative ")
else :
    print(f"{num} is zero.")
# Out:
# 0 is zero

# %%
print("bhi paper ha mid ka is lya streak na toot jaha khin")
# Out:
# bhi paper ha mid ka is lya streak na toot jaha khin

# %%
print("bhi paper ha mid ka is lya streak na toot jaha khin")
# Out:
# bhi paper ha mid ka is lya streak na toot jaha khin

# %%
print("bhi paper ha mid ka is lya streak na toot jaha khin")
# Out:
# bhi paper ha mid ka is lya streak na toot jaha khin

# %%
print("bhi paper ha mid ka is lya streak na toot jaha khin")
# Out:
# bhi paper ha mid ka is lya streak na toot jaha khin

# %%
print("bhi paper ha mid ka is lya streak na toot jaha khin")
# Out:
# bhi paper ha mid ka is lya streak na toot jaha khin

# %%
print("bhi paper ha mid ka is lya streak na toot jaha khin")
# Out:
# bhi paper ha mid ka is lya streak na toot jaha khin
